# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
weight = np.random.normal(loc=65,scale=5,size=80000000)

# %%
np.mean(weight)
# Out:
# np.float64(105.00026147281362)

# %%
np.std(weight)
# Out:
# np.float64(9.999675445741362)

# %%
np.max(weight) - np.min(weight)
# Out:
# np.float64(57.97719733053509)

# %%
plt.hist(weight,bins=100)
plt.xlabel("Weight(X)")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')
